# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import pickle

# %%
cv = CountVectorizer(max_features=5000,stop_words='english')

# %%
new=pd.read_csv("C:/Users/niraj/Desktop/study/machine learning/movie_recomandation_system/data/preprocessed.csv")

# %%
vector = cv.fit_transform(new['tags']).toarray()

# %%
vector.shape
# Out:
# (4806, 5000)

# %%
similarity = cosine_similarity(vector)

# %%
similarity
# Out:
# array([[1.        , 0.08858079, 0.05905386, ..., 0.02478408, 0.02599376,
#         0.        ],
#        [0.08858079, 1.        , 0.06451613, ..., 0.02707652, 0.        ,
#         0.        ],
#        [0.05905386, 0.06451613, 1.        , ..., 0.02707652, 0.        ,
#         0.        ],
#        ...,
#        [0.02478408, 0.02707652, 0.02707652, ..., 1.        , 0.07150969,
#         0.0489116 ],
#        [0.02599376, 0.        , 0.        , ..., 0.07150969, 1.        ,
#         0.05129892],
#        [0.        , 0.        , 0.        , ..., 0.0489116 , 0.05129892,
#         1.        ]], shape=(4806, 4806))

# %%
new[new['title'] == 'The Lego Movie'].index[0]
# Out:
# np.int64(744)

# %%
def recommend(movie):
    index = new[new['title'] == movie].index[0]
    distances = sorted(list(enumerate(similarity[index])),reverse=True,key = lambda x: x[1])
    for i in distances[1:6]:
        print(new.iloc[i[0]].title)

# %%
recommend('Gandhi')
# Out:
# Gandhi, My Father
# The Wind That Shakes the Barley
# A Passage to India
# Guiana 1838
# Ramanujan

# %%
pickle.dump(new,open('C:/Users/niraj/Desktop/study/machine learning/movie_recomandation_system/artifacts/movie_list.pkl','wb'))
pickle.dump(similarity,open('C:/Users/niraj/Desktop/study/machine learning/movie_recomandation_system/artifacts/similarity.pkl','wb'))
